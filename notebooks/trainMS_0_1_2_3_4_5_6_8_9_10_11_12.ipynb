# %%
# !git clone https://github.com/676627/deep-learning-eurosat.git
# %cd deep-learning-eurosat
# !pip install -q rasterio wandb
# Out:
# Cloning into 'deep-learning-eurosat'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (403/403), done.
# remote: Compressing objects: 100% (243/243), done.
# remote: Total 403 (delta 185), reused 354 (delta 139), pack-reused 0 (from 0)
# Receiving objects: 100% (403/403), 8.18 MiB | 12.58 MiB/s, done.
# Resolving deltas: 100% (185/185), done.
# /content/deep-learning-eurosat

# %%
# !wget -q "https://zenodo.org/records/7711810/files/EuroSAT_MS.zip"

# %%
# !unzip -q EuroSAT_MS.zip -d data/

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: 676627 (180240-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python src/train.py --mode ms --model_version batchnorm_3conv --lr 1e-4 --dropout 0.4 --band_indices 0 1 2 3 4 5 6 8 9 10 11 12
# Out:
# 2026-04-27 15:36:16.052122: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777304176.072286    8474 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777304176.079047    8474 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777304176.094864    8474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777304176.094911    8474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777304176.094916    8474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777304176.094920    8474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-27 15:36:16.099363: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 27000 images | 21600 train, 5400 val | 12 bands
# Estimating normalisation stats from 2000 training images...
# Sampling: 100% 2000/2000 [00:04<00:00, 432.61it/s]
# 2026-04-27 15:36:27.694068: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777304187.695570    8474 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Saved normalization stats to checkpoints/MS_batchnorm_3conv_bands0_1_2_3_4_5_6_8_9_10_11_12_full_stats.json
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 64, 64, 12)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 64, 64, 12)     │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 64)     │         6,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 62, 62, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 29, 29, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 29, 29, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        92,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 469,514 (1.79 MB)
#  Trainable params: 468,618 (1.79 MB)
#  Non-trainable params: 896 (3.50 KB)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: 676627 (180240-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/deep-learning-eurosat/wandb/run-20260427_153630-gvxuhs9u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MS_batchnorm_3conv_bands0_1_2_3_4_5_6_8_9_10_11_12_full
# wandb: ⭐️ View project at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: 🚀 View run at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/gvxuhs9u
# Epoch 1/50
# I0000 00:00:1777304201.028073    8548 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 123s 341ms/step - accuracy: 0.7433 - loss: 0.7672 - val_accuracy: 0.8276 - val_loss: 0.5014 - learning_rate: 1.0000e-04
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 334ms/step - accuracy: 0.8570 - loss: 0.4223 - val_accuracy: 0.9002 - val_loss: 0.3045 - learning_rate: 1.0000e-04
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 336ms/step - accuracy: 0.8888 - loss: 0.3329 - val_accuracy: 0.9224 - val_loss: 0.2286 - learning_rate: 1.0000e-04
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 336ms/step - accuracy: 0.9017 - loss: 0.2866 - val_accuracy: 0.9057 - val_loss: 0.2981 - learning_rate: 1.0000e-04
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 334ms/step - accuracy: 0.9150 - loss: 0.2567 - val_accuracy: 0.9296 - val_loss: 0.2179 - learning_rate: 1.0000e-04
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 336ms/step - accuracy: 0.9232 - loss: 0.2302 - val_accuracy: 0.9398 - val_loss: 0.1934 - learning_rate: 1.0000e-04
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 115s 339ms/step - accuracy: 0.9303 - loss: 0.2131 - val_accuracy: 0.9441 - val_loss: 0.1763 - learning_rate: 1.0000e-04
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 143s 342ms/step - accuracy: 0.9312 - loss: 0.2002 - val_accuracy: 0.9424 - val_loss: 0.1934 - learning_rate: 1.0000e-04
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 337ms/step - accuracy: 0.9405 - loss: 0.1807 - val_accuracy: 0.9381 - val_loss: 0.2139 - learning_rate: 1.0000e-04
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 141s 334ms/step - accuracy: 0.9415 - loss: 0.1774 - val_accuracy: 0.9550 - val_loss: 0.1522 - learning_rate: 1.0000e-04
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 336ms/step - accuracy: 0.9446 - loss: 0.1680 - val_accuracy: 0.9469 - val_loss: 0.1717 - learning_rate: 1.0000e-04
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 137s 407ms/step - accuracy: 0.9495 - loss: 0.1548 - val_accuracy: 0.9252 - val_loss: 0.2713 - learning_rate: 1.0000e-04
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9518 - loss: 0.1489 - val_accuracy: 0.9513 - val_loss: 0.1650 - learning_rate: 1.0000e-04
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 145s 345ms/step - accuracy: 0.9534 - loss: 0.1404 - val_accuracy: 0.9567 - val_loss: 0.1531 - learning_rate: 1.0000e-04
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 115s 339ms/step - accuracy: 0.9568 - loss: 0.1355 - val_accuracy: 0.9544 - val_loss: 0.1534 - learning_rate: 1.0000e-04
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 115s 340ms/step - accuracy: 0.9569 - loss: 0.1336 - val_accuracy: 0.9565 - val_loss: 0.1395 - learning_rate: 1.0000e-04
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 336ms/step - accuracy: 0.9602 - loss: 0.1252 - val_accuracy: 0.9570 - val_loss: 0.1352 - learning_rate: 1.0000e-04
# Epoch 18/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9600 - loss: 0.1203 - val_accuracy: 0.9587 - val_loss: 0.1306 - learning_rate: 1.0000e-04
# Epoch 19/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 337ms/step - accuracy: 0.9599 - loss: 0.1217 - val_accuracy: 0.9519 - val_loss: 0.1623 - learning_rate: 1.0000e-04
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 332ms/step - accuracy: 0.9627 - loss: 0.1121 - val_accuracy: 0.9500 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 333ms/step - accuracy: 0.9650 - loss: 0.1123 - val_accuracy: 0.9317 - val_loss: 0.2501 - learning_rate: 1.0000e-04
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9643 - loss: 0.1080 - val_accuracy: 0.9511 - val_loss: 0.1716 - learning_rate: 1.0000e-04
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 142s 336ms/step - accuracy: 0.9657 - loss: 0.1102 - val_accuracy: 0.9470 - val_loss: 0.1928 - learning_rate: 1.0000e-04
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9660 - loss: 0.1023 - val_accuracy: 0.9265 - val_loss: 0.2693 - learning_rate: 1.0000e-04
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 336ms/step - accuracy: 0.9696 - loss: 0.0918 - val_accuracy: 0.9663 - val_loss: 0.1158 - learning_rate: 1.0000e-04
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9650 - loss: 0.1050 - val_accuracy: 0.9630 - val_loss: 0.1260 - learning_rate: 1.0000e-04
# Epoch 27/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 133s 395ms/step - accuracy: 0.9693 - loss: 0.0935 - val_accuracy: 0.9581 - val_loss: 0.1578 - learning_rate: 1.0000e-04
# Epoch 28/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 333ms/step - accuracy: 0.9702 - loss: 0.0882 - val_accuracy: 0.9670 - val_loss: 0.1157 - learning_rate: 1.0000e-04
# Epoch 29/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 332ms/step - accuracy: 0.9713 - loss: 0.0857 - val_accuracy: 0.9733 - val_loss: 0.0924 - learning_rate: 1.0000e-04
# Epoch 30/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 338ms/step - accuracy: 0.9717 - loss: 0.0862 - val_accuracy: 0.9628 - val_loss: 0.1254 - learning_rate: 1.0000e-04
# Epoch 31/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 333ms/step - accuracy: 0.9715 - loss: 0.0862 - val_accuracy: 0.9654 - val_loss: 0.1192 - learning_rate: 1.0000e-04
# Epoch 32/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9722 - loss: 0.0840 - val_accuracy: 0.9546 - val_loss: 0.1562 - learning_rate: 1.0000e-04
# Epoch 33/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 115s 339ms/step - accuracy: 0.9733 - loss: 0.0840 - val_accuracy: 0.9711 - val_loss: 0.1032 - learning_rate: 1.0000e-04
# Epoch 34/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 336ms/step - accuracy: 0.9727 - loss: 0.0840 - val_accuracy: 0.9626 - val_loss: 0.1216 - learning_rate: 1.0000e-04
# Epoch 35/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 337ms/step - accuracy: 0.9725 - loss: 0.0829 - val_accuracy: 0.9665 - val_loss: 0.1161 - learning_rate: 1.0000e-04
# Epoch 36/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 141s 336ms/step - accuracy: 0.9747 - loss: 0.0773 - val_accuracy: 0.9596 - val_loss: 0.1428 - learning_rate: 1.0000e-04
# Epoch 37/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 115s 340ms/step - accuracy: 0.9745 - loss: 0.0744 - val_accuracy: 0.9681 - val_loss: 0.1094 - learning_rate: 1.0000e-04
# Epoch 38/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9824 - loss: 0.0528 - val_accuracy: 0.9657 - val_loss: 0.1192 - learning_rate: 5.0000e-05
# Epoch 39/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 335ms/step - accuracy: 0.9819 - loss: 0.0527 - val_accuracy: 0.9680 - val_loss: 0.1081 - learning_rate: 5.0000e-05
# Epoch 40/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 134s 396ms/step - accuracy: 0.9830 - loss: 0.0515 - val_accuracy: 0.9689 - val_loss: 0.1137 - learning_rate: 5.0000e-05
# Epoch 41/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 116s 344ms/step - accuracy: 0.9833 - loss: 0.0517 - val_accuracy: 0.9722 - val_loss: 0.1048 - learning_rate: 5.0000e-05
# Epoch 42/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 333ms/step - accuracy: 0.9842 - loss: 0.0479 - val_accuracy: 0.9691 - val_loss: 0.1095 - learning_rate: 5.0000e-05
# Epoch 43/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 142s 334ms/step - accuracy: 0.9833 - loss: 0.0517 - val_accuracy: 0.9743 - val_loss: 0.0944 - learning_rate: 5.0000e-05
# Epoch 44/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9816 - loss: 0.0515 - val_accuracy: 0.9687 - val_loss: 0.1059 - learning_rate: 5.0000e-05
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading output.log 10.4KB/10.4KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 295B/295B (0.1s)
# wandb: ⣷ uploading config.yaml 3.1KB/3.1KB (0.1s)
# wandb: ⣯ uploading output.log 10.4KB/10.4KB (0.1s)
# wandb: ⣯ uploading wandb-summary.json 295B/295B (0.1s)
# wandb: ⣯ uploading config.yaml 3.1KB/3.1KB (0.1s)
# wandb: ⣟ uploading output.log 10.4KB/10.4KB (0.1s)
# wandb: ⣟ uploading wandb-summary.json 295B/295B (0.1s)
# wandb: ⣟ uploading config.yaml 3.1KB/3.1KB (0.1s)
# wandb: ⡿ uploading output.log 10.4KB/10.4KB (0.1s)
# wandb: ⡿ uploading wandb-summary.json 295B/295B (0.1s)
# wandb: ⡿ uploading config.yaml 3.1KB/3.1KB (0.1s)
# wandb:
# wandb: Run history:
# wandb:      epoch/accuracy ▁▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇████████████████
# wandb:         epoch/epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: epoch/learning_rate ██████████████████████████████████▁▁▁▁▁▁
# wandb:          epoch/loss █▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  epoch/val_accuracy ▁▄▆▅▆▆▇▇▆▇▆▇▇▇▇▇▇▇▇▆▇▆██▇██▇█▇▇█▇███████
# wandb:      epoch/val_loss █▅▃▅▃▃▂▃▃▂▄▂▂▂▂▂▂▂▂▄▃▄▁▂▂▁▁▂▁▂▁▁▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch/accuracy 0.98162
# wandb:         epoch/epoch 43
# wandb: epoch/learning_rate 5e-05
# wandb:          epoch/loss 0.05147
# wandb:  epoch/val_accuracy 0.9687
# wandb:      epoch/val_loss 0.10595
# wandb:
# wandb: 🚀 View run MS_batchnorm_3conv_bands0_1_2_3_4_5_6_8_9_10_11_12_full at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/gvxuhs9u
# wandb: ⭐️ View project at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260427_153630-gvxuhs9u/logs

# %%
# !python src/evaluate.py
# Out:
# 2026-04-27 17:08:41.256117: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777309721.276114   32774 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777309721.283039   32774 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777309721.298848   32774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777309721.298894   32774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777309721.298899   32774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777309721.298903   32774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-27 17:08:41.303280: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 27000 images | 21600 train, 5400 val | 12 bands
# Estimating normalisation stats from 2000 training images...
# Sampling: 100% 2000/2000 [00:05<00:00, 364.88it/s]
# 2026-04-27 17:08:51.954027: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777309731.955490   32774 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777309735.062734   32842 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-27 17:09:19.663001: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9743  (97.43%)
#                       precision    recall  f1-score   support
#
#           AnnualCrop       0.98      0.97      0.98       610
#               Forest       0.99      1.00      0.99       598
# HerbaceousVegetation       0.99      0.98      0.98       605
#              Highway       0.96      0.92      0.94       523
#           Industrial       0.96      0.96      0.96       500
#              Pasture       0.96      0.98      0.97       383
#        PermanentCrop       0.97      0.97      0.97       506
#          Residential       0.95      1.00      0.98       608
#                River       0.97      0.98      0.97       494
#              SeaLake       0.99      0.99      0.99       573
#
#             accuracy                           0.97      5400
#            macro avg       0.97      0.97      0.97      5400
#         weighted avg       0.97      0.97      0.97      5400
#
# Figure(1000x800)
