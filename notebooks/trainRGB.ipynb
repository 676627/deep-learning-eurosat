# %%
# !git clone https://github.com/676627/deep-learning-eurosat.git
# %cd deep-learning-eurosat
# !pip install -q rasterio wandb
# Out:
# Cloning into 'deep-learning-eurosat'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (403/403), done.
# remote: Compressing objects: 100% (243/243), done.
# remote: Total 403 (delta 185), reused 354 (delta 139), pack-reused 0 (from 0)
# Receiving objects: 100% (403/403), 8.18 MiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (185/185), done.
# /content/deep-learning-eurosat/deep-learning-eurosat

# %%
# Download and unzip data
# !wget -q "https://zenodo.org/records/7711810/files/EuroSAT_RGB.zip"

# !unzip -q EuroSAT_RGB.zip -d data/

# %%
import wandb
wandb.login()
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: 676627 (180240-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !python src/train.py --mode rgb --model_version batchnorm_3conv --lr 1e-4 --dropout 0.3
# Out:
# 2026-04-27 14:17:20.859170: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777299440.879807    3759 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777299440.886549    3759 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777299440.902104    3759 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777299440.902151    3759 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777299440.902167    3759 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777299440.902173    3759 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Using 5400 files for validation.
# 2026-04-27 14:17:27.942678: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777299447.945107    3759 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 64, 64, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 64)     │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 62, 62, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 29, 29, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 29, 29, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        92,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,330 (1.77 MB)
#  Trainable params: 463,434 (1.77 MB)
#  Non-trainable params: 896 (3.50 KB)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: 676627 (180240-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run ed7nw1iy (0.4s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/deep-learning-eurosat/deep-learning-eurosat/wandb/run-20260427_141731-ed7nw1iy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RGB_batchnorm_3conv_full
# wandb: ⭐️ View project at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: 🚀 View run at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/ed7nw1iy
# Epoch 1/50
# I0000 00:00:1777299460.611397    3809 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.6282 - loss: 1.0641 - val_accuracy: 0.1972 - val_loss: 3.5899 - learning_rate: 1.0000e-04
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.7348 - loss: 0.7487 - val_accuracy: 0.7191 - val_loss: 0.9076 - learning_rate: 1.0000e-04
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.7678 - loss: 0.6677 - val_accuracy: 0.7552 - val_loss: 0.7095 - learning_rate: 1.0000e-04
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.7872 - loss: 0.6049 - val_accuracy: 0.7515 - val_loss: 0.7513 - learning_rate: 1.0000e-04
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.8007 - loss: 0.5584 - val_accuracy: 0.7830 - val_loss: 0.6480 - learning_rate: 1.0000e-04
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.8204 - loss: 0.5119 - val_accuracy: 0.7707 - val_loss: 0.7047 - learning_rate: 1.0000e-04
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8360 - loss: 0.4706 - val_accuracy: 0.8139 - val_loss: 0.5587 - learning_rate: 1.0000e-04
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8426 - loss: 0.4516 - val_accuracy: 0.8335 - val_loss: 0.5021 - learning_rate: 1.0000e-04
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8537 - loss: 0.4238 - val_accuracy: 0.8461 - val_loss: 0.4343 - learning_rate: 1.0000e-04
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8584 - loss: 0.4076 - val_accuracy: 0.8659 - val_loss: 0.3847 - learning_rate: 1.0000e-04
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.8662 - loss: 0.3849 - val_accuracy: 0.8598 - val_loss: 0.4230 - learning_rate: 1.0000e-04
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8768 - loss: 0.3618 - val_accuracy: 0.8685 - val_loss: 0.3947 - learning_rate: 1.0000e-04
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8805 - loss: 0.3433 - val_accuracy: 0.8598 - val_loss: 0.4330 - learning_rate: 1.0000e-04
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8856 - loss: 0.3285 - val_accuracy: 0.8709 - val_loss: 0.3978 - learning_rate: 1.0000e-04
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8866 - loss: 0.3240 - val_accuracy: 0.8950 - val_loss: 0.3113 - learning_rate: 1.0000e-04
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8946 - loss: 0.3085 - val_accuracy: 0.8265 - val_loss: 0.5293 - learning_rate: 1.0000e-04
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8935 - loss: 0.3063 - val_accuracy: 0.8965 - val_loss: 0.3045 - learning_rate: 1.0000e-04
# Epoch 18/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8988 - loss: 0.2889 - val_accuracy: 0.8931 - val_loss: 0.3363 - learning_rate: 1.0000e-04
# Epoch 19/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9011 - loss: 0.2855 - val_accuracy: 0.9183 - val_loss: 0.2526 - learning_rate: 1.0000e-04
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.9073 - loss: 0.2715 - val_accuracy: 0.8900 - val_loss: 0.3238 - learning_rate: 1.0000e-04
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9047 - loss: 0.2748 - val_accuracy: 0.8974 - val_loss: 0.3216 - learning_rate: 1.0000e-04
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9052 - loss: 0.2735 - val_accuracy: 0.8798 - val_loss: 0.3378 - learning_rate: 1.0000e-04
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9136 - loss: 0.2515 - val_accuracy: 0.9022 - val_loss: 0.3017 - learning_rate: 1.0000e-04
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9103 - loss: 0.2561 - val_accuracy: 0.8502 - val_loss: 0.5353 - learning_rate: 1.0000e-04
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9159 - loss: 0.2408 - val_accuracy: 0.8604 - val_loss: 0.4662 - learning_rate: 1.0000e-04
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9185 - loss: 0.2346 - val_accuracy: 0.9102 - val_loss: 0.2794 - learning_rate: 1.0000e-04
# Epoch 27/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9212 - loss: 0.2262 - val_accuracy: 0.9002 - val_loss: 0.3009 - learning_rate: 1.0000e-04
# Epoch 28/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9322 - loss: 0.1958 - val_accuracy: 0.9091 - val_loss: 0.3025 - learning_rate: 5.0000e-05
# Epoch 29/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9346 - loss: 0.1880 - val_accuracy: 0.9156 - val_loss: 0.2600 - learning_rate: 5.0000e-05
# Epoch 30/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 0.9352 - loss: 0.1863 - val_accuracy: 0.8563 - val_loss: 0.5099 - learning_rate: 5.0000e-05
# Epoch 31/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9334 - loss: 0.1899 - val_accuracy: 0.9191 - val_loss: 0.2465 - learning_rate: 5.0000e-05
# Epoch 32/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.9351 - loss: 0.1859 - val_accuracy: 0.9244 - val_loss: 0.2394 - learning_rate: 5.0000e-05
# Epoch 33/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9367 - loss: 0.1806 - val_accuracy: 0.9026 - val_loss: 0.2931 - learning_rate: 5.0000e-05
# Epoch 34/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9380 - loss: 0.1735 - val_accuracy: 0.9033 - val_loss: 0.3455 - learning_rate: 5.0000e-05
# Epoch 35/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9369 - loss: 0.1820 - val_accuracy: 0.8906 - val_loss: 0.3638 - learning_rate: 5.0000e-05
# Epoch 36/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9380 - loss: 0.1775 - val_accuracy: 0.9026 - val_loss: 0.3222 - learning_rate: 5.0000e-05
# Epoch 37/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 0.9403 - loss: 0.1730 - val_accuracy: 0.8809 - val_loss: 0.3999 - learning_rate: 5.0000e-05
# Epoch 38/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9412 - loss: 0.1748 - val_accuracy: 0.9204 - val_loss: 0.2682 - learning_rate: 5.0000e-05
# Epoch 39/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.9431 - loss: 0.1659 - val_accuracy: 0.8665 - val_loss: 0.4441 - learning_rate: 5.0000e-05
# Epoch 40/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.9427 - loss: 0.1629 - val_accuracy: 0.9037 - val_loss: 0.3471 - learning_rate: 5.0000e-05
# Epoch 41/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.9482 - loss: 0.1495 - val_accuracy: 0.8913 - val_loss: 0.3897 - learning_rate: 2.5000e-05
# Epoch 42/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9511 - loss: 0.1427 - val_accuracy: 0.9061 - val_loss: 0.3380 - learning_rate: 2.5000e-05
# Epoch 43/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9494 - loss: 0.1485 - val_accuracy: 0.9004 - val_loss: 0.3764 - learning_rate: 2.5000e-05
# Epoch 44/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9489 - loss: 0.1465 - val_accuracy: 0.8891 - val_loss: 0.3921 - learning_rate: 2.5000e-05
# Epoch 45/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9513 - loss: 0.1451 - val_accuracy: 0.8994 - val_loss: 0.3321 - learning_rate: 2.5000e-05
# Epoch 46/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.9492 - loss: 0.1458 - val_accuracy: 0.8837 - val_loss: 0.3972 - learning_rate: 2.5000e-05
# Epoch 47/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9531 - loss: 0.1394 - val_accuracy: 0.9083 - val_loss: 0.3276 - learning_rate: 2.5000e-05
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading output.log 11.0KB/11.0KB (0.2s)
# wandb: ⣷ uploading wandb-summary.json 291B/291B (0.2s)
# wandb: ⣷ uploading config.yaml 2.6KB/2.6KB (0.2s)
# wandb: ⣯ uploading output.log 11.0KB/11.0KB (0.2s)
# wandb: ⣯ uploading wandb-summary.json 291B/291B (0.2s)
# wandb: ⣯ uploading config.yaml 2.6KB/2.6KB (0.2s)
# wandb: ⣟ uploading output.log 11.0KB/11.0KB (0.2s)
# wandb: ⣟ uploading wandb-summary.json 291B/291B (0.2s)
# wandb: ⣟ uploading config.yaml 2.6KB/2.6KB (0.2s)
# wandb:
# wandb: Run history:
# wandb:      epoch/accuracy ▁▃▄▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████████
# wandb:         epoch/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb: epoch/learning_rate ███████████████████████▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁▁
# wandb:          epoch/loss █▆▅▅▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  epoch/val_accuracy ▁▆▆▆▇▇▇▇▇▇▇▇█▇██████▇▇███▇███████▇██████
# wandb:      epoch/val_loss █▂▂▂▂▂▂▁▁▁▁▁▁▂▁▁▁▁▁▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch/accuracy 0.9531
# wandb:         epoch/epoch 46
# wandb: epoch/learning_rate 2e-05
# wandb:          epoch/loss 0.13945
# wandb:  epoch/val_accuracy 0.90833
# wandb:      epoch/val_loss 0.3276
# wandb:
# wandb: 🚀 View run RGB_batchnorm_3conv_full at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/ed7nw1iy
# wandb: ⭐️ View project at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260427_141731-ed7nw1iy/logs

# %%
# !python src/evaluate.py
# Out:
# 2026-04-27 14:37:56.079553: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777300676.100790    9950 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777300676.107900    9950 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777300676.123834    9950 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777300676.123875    9950 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777300676.123879    9950 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777300676.123883    9950 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Using 5400 files for validation.
# 2026-04-27 14:38:01.223663: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777300681.225120    9950 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777300685.015297    9996 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Validation accuracy: 0.9244  (92.44%)
#                       precision    recall  f1-score   support
#
#           AnnualCrop       0.97      0.89      0.93       597
#               Forest       0.96      0.99      0.98       600
# HerbaceousVegetation       0.92      0.86      0.89       557
#              Highway       0.85      0.93      0.89       493
#           Industrial       0.95      0.94      0.94       512
#              Pasture       0.91      0.96      0.93       374
#        PermanentCrop       0.92      0.84      0.88       491
#          Residential       0.86      1.00      0.92       607
#                River       0.92      0.87      0.89       547
#              SeaLake       0.99      0.96      0.97       622
#
#             accuracy                           0.92      5400
#            macro avg       0.92      0.92      0.92      5400
#         weighted avg       0.93      0.92      0.92      5400
#
# Figure(1000x800)

# %%
# !python src/train.py --mode rgb --model_version batchnorm_3conv --lr 1e-4 --dropout 0.4
# Out:
# 2026-04-27 14:38:47.673537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777300727.695238   10927 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777300727.702263   10927 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777300727.719168   10927 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777300727.719224   10927 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777300727.719229   10927 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777300727.719233   10927 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Using 5400 files for validation.
# 2026-04-27 14:38:54.569372: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777300734.570848   10927 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 64, 64, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 64)     │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 62, 62, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 29, 29, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 29, 29, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        92,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,330 (1.77 MB)
#  Trainable params: 463,434 (1.77 MB)
#  Non-trainable params: 896 (3.50 KB)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: 676627 (180240-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run cwsmxa26 (0.4s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/deep-learning-eurosat/deep-learning-eurosat/wandb/run-20260427_143858-cwsmxa26
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RGB_batchnorm_3conv_full
# wandb: ⭐️ View project at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: 🚀 View run at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/cwsmxa26
# Epoch 1/50
# I0000 00:00:1777300748.293792   10983 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.5953 - loss: 1.1858 - val_accuracy: 0.1569 - val_loss: 3.6237 - learning_rate: 1.0000e-04
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.7094 - loss: 0.8353 - val_accuracy: 0.7417 - val_loss: 0.7643 - learning_rate: 1.0000e-04
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.7486 - loss: 0.7241 - val_accuracy: 0.7717 - val_loss: 0.6745 - learning_rate: 1.0000e-04
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.7663 - loss: 0.6706 - val_accuracy: 0.7796 - val_loss: 0.6743 - learning_rate: 1.0000e-04
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.7837 - loss: 0.6172 - val_accuracy: 0.7237 - val_loss: 0.9362 - learning_rate: 1.0000e-04
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8042 - loss: 0.5599 - val_accuracy: 0.7193 - val_loss: 0.9543 - learning_rate: 1.0000e-04
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8177 - loss: 0.5305 - val_accuracy: 0.7506 - val_loss: 0.7846 - learning_rate: 1.0000e-04
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8286 - loss: 0.4961 - val_accuracy: 0.7891 - val_loss: 0.6293 - learning_rate: 1.0000e-04
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8337 - loss: 0.4829 - val_accuracy: 0.8322 - val_loss: 0.4958 - learning_rate: 1.0000e-04
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8426 - loss: 0.4567 - val_accuracy: 0.8211 - val_loss: 0.5736 - learning_rate: 1.0000e-04
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8510 - loss: 0.4291 - val_accuracy: 0.8509 - val_loss: 0.4306 - learning_rate: 1.0000e-04
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8550 - loss: 0.4188 - val_accuracy: 0.8696 - val_loss: 0.3877 - learning_rate: 1.0000e-04
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8683 - loss: 0.3780 - val_accuracy: 0.8126 - val_loss: 0.5782 - learning_rate: 1.0000e-04
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8691 - loss: 0.3760 - val_accuracy: 0.8404 - val_loss: 0.4522 - learning_rate: 1.0000e-04
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8756 - loss: 0.3579 - val_accuracy: 0.8378 - val_loss: 0.4850 - learning_rate: 1.0000e-04
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8784 - loss: 0.3486 - val_accuracy: 0.7746 - val_loss: 0.7285 - learning_rate: 1.0000e-04
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8812 - loss: 0.3438 - val_accuracy: 0.8607 - val_loss: 0.4710 - learning_rate: 1.0000e-04
# Epoch 18/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8853 - loss: 0.3277 - val_accuracy: 0.8674 - val_loss: 0.3961 - learning_rate: 1.0000e-04
# Epoch 19/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8902 - loss: 0.3145 - val_accuracy: 0.7970 - val_loss: 0.6281 - learning_rate: 1.0000e-04
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8948 - loss: 0.3043 - val_accuracy: 0.8706 - val_loss: 0.4043 - learning_rate: 1.0000e-04
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.9056 - loss: 0.2671 - val_accuracy: 0.8106 - val_loss: 0.5706 - learning_rate: 5.0000e-05
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9056 - loss: 0.2708 - val_accuracy: 0.8837 - val_loss: 0.3487 - learning_rate: 5.0000e-05
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9106 - loss: 0.2562 - val_accuracy: 0.9041 - val_loss: 0.3051 - learning_rate: 5.0000e-05
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9127 - loss: 0.2537 - val_accuracy: 0.8974 - val_loss: 0.3115 - learning_rate: 5.0000e-05
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9118 - loss: 0.2484 - val_accuracy: 0.8985 - val_loss: 0.3183 - learning_rate: 5.0000e-05
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9153 - loss: 0.2426 - val_accuracy: 0.8969 - val_loss: 0.3211 - learning_rate: 5.0000e-05
# Epoch 27/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9182 - loss: 0.2372 - val_accuracy: 0.8850 - val_loss: 0.3360 - learning_rate: 5.0000e-05
# Epoch 28/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9187 - loss: 0.2306 - val_accuracy: 0.8924 - val_loss: 0.3327 - learning_rate: 5.0000e-05
# Epoch 29/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9210 - loss: 0.2275 - val_accuracy: 0.9059 - val_loss: 0.2732 - learning_rate: 5.0000e-05
# Epoch 30/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9239 - loss: 0.2196 - val_accuracy: 0.8843 - val_loss: 0.3656 - learning_rate: 5.0000e-05
# Epoch 31/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9205 - loss: 0.2283 - val_accuracy: 0.8848 - val_loss: 0.3833 - learning_rate: 5.0000e-05
# Epoch 32/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9202 - loss: 0.2242 - val_accuracy: 0.9259 - val_loss: 0.2323 - learning_rate: 5.0000e-05
# Epoch 33/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9271 - loss: 0.2164 - val_accuracy: 0.8885 - val_loss: 0.3293 - learning_rate: 5.0000e-05
# Epoch 34/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9241 - loss: 0.2131 - val_accuracy: 0.8756 - val_loss: 0.3979 - learning_rate: 5.0000e-05
# Epoch 35/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9243 - loss: 0.2189 - val_accuracy: 0.8861 - val_loss: 0.3781 - learning_rate: 5.0000e-05
# Epoch 36/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9246 - loss: 0.2144 - val_accuracy: 0.8763 - val_loss: 0.3716 - learning_rate: 5.0000e-05
# Epoch 37/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9267 - loss: 0.2101 - val_accuracy: 0.8689 - val_loss: 0.4543 - learning_rate: 5.0000e-05
# Epoch 38/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9276 - loss: 0.2101 - val_accuracy: 0.9146 - val_loss: 0.2649 - learning_rate: 5.0000e-05
# Epoch 39/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9301 - loss: 0.2032 - val_accuracy: 0.8815 - val_loss: 0.3926 - learning_rate: 5.0000e-05
# Epoch 40/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9302 - loss: 0.2019 - val_accuracy: 0.9148 - val_loss: 0.2560 - learning_rate: 5.0000e-05
# Epoch 41/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9363 - loss: 0.1845 - val_accuracy: 0.8763 - val_loss: 0.4501 - learning_rate: 2.5000e-05
# Epoch 42/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9370 - loss: 0.1783 - val_accuracy: 0.9031 - val_loss: 0.2945 - learning_rate: 2.5000e-05
# Epoch 43/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9367 - loss: 0.1827 - val_accuracy: 0.8937 - val_loss: 0.3239 - learning_rate: 2.5000e-05
# Epoch 44/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9406 - loss: 0.1760 - val_accuracy: 0.9065 - val_loss: 0.3056 - learning_rate: 2.5000e-05
# Epoch 45/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9391 - loss: 0.1799 - val_accuracy: 0.8843 - val_loss: 0.3755 - learning_rate: 2.5000e-05
# Epoch 46/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9379 - loss: 0.1758 - val_accuracy: 0.8956 - val_loss: 0.3441 - learning_rate: 2.5000e-05
# Epoch 47/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.9404 - loss: 0.1706 - val_accuracy: 0.8954 - val_loss: 0.3348 - learning_rate: 2.5000e-05
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading history steps 46-46, summary, console lines 93-93 (0.0s)
# wandb: ⣯ uploading history steps 46-46, summary, console lines 93-93 (0.0s)
# wandb:
# wandb: Run history:
# wandb:      epoch/accuracy ▁▃▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█████████████████
# wandb:         epoch/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb: epoch/learning_rate █████████████████▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁▁
# wandb:          epoch/loss █▆▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  epoch/val_accuracy ▁▆▇▇▆▆▇▇▇▇▇▇▇▇▇▇▇▇█████████████▇████████
# wandb:      epoch/val_loss █▂▂▂▂▂▂▂▂▁▁▂▂▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch/accuracy 0.94042
# wandb:         epoch/epoch 46
# wandb: epoch/learning_rate 2e-05
# wandb:          epoch/loss 0.17062
# wandb:  epoch/val_accuracy 0.89537
# wandb:      epoch/val_loss 0.33478
# wandb:
# wandb: 🚀 View run RGB_batchnorm_3conv_full at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/cwsmxa26
# wandb: ⭐️ View project at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260427_143858-cwsmxa26/logs

# %%
# !python src/evaluate.py
# Out:
# 2026-04-27 14:53:10.476604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777301590.497773   15586 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777301590.504877   15586 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777301590.521772   15586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777301590.521818   15586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777301590.521825   15586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777301590.521831   15586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Using 5400 files for validation.
# 2026-04-27 14:53:16.547629: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777301596.549147   15586 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777301599.247650   15638 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Validation accuracy: 0.9259  (92.59%)
#                       precision    recall  f1-score   support
#
#           AnnualCrop       0.97      0.90      0.93       597
#               Forest       0.96      0.99      0.97       600
# HerbaceousVegetation       0.92      0.87      0.89       557
#              Highway       0.91      0.86      0.89       493
#           Industrial       0.96      0.91      0.93       512
#              Pasture       0.92      0.95      0.93       374
#        PermanentCrop       0.87      0.88      0.87       491
#          Residential       0.87      1.00      0.93       607
#                River       0.90      0.90      0.90       547
#              SeaLake       0.98      0.98      0.98       622
#
#             accuracy                           0.93      5400
#            macro avg       0.93      0.92      0.92      5400
#         weighted avg       0.93      0.93      0.93      5400
#
# Figure(1000x800)
