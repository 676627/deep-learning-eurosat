# %%
# !git clone https://github.com/676627/deep-learning-eurosat.git
# %cd deep-learning-eurosat
# !pip install -q rasterio wandb
# Out:
# Cloning into 'deep-learning-eurosat'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (455/455), done.
# remote: Compressing objects: 100% (287/287), done.
# remote: Total 455 (delta 216), reused 381 (delta 145), pack-reused 0 (from 0)
# Receiving objects: 100% (455/455), 9.41 MiB | 10.94 MiB/s, done.
# Resolving deltas: 100% (216/216), done.
# /content/deep-learning-eurosat

# %%
# !wget -q "https://zenodo.org/records/7711810/files/EuroSAT_MS.zip"

# %%
# !unzip -q EuroSAT_MS.zip -d data/

# %%
import wandb
wandb.login()
# Out:
# True

# %%
# !python src/train.py --mode ms --model_version batchnorm_3conv --lr 1e-4 --dropout 0.4 --band_indices 0 1 2 3 9 10 11 12
# Out:
# 2026-04-28 10:20:54.975453: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777371654.996071    4308 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777371655.003666    4308 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777371655.021297    4308 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777371655.021336    4308 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777371655.021345    4308 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777371655.021350    4308 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-28 10:20:55.025743: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 27000 images | 21600 train, 5400 val | 8 bands
# Estimating normalisation stats from 2000 training images...
# Sampling: 100% 2000/2000 [00:05<00:00, 342.61it/s]
# 2026-04-28 10:21:08.795506: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777371668.799964    4308 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Using 8 bands:
#   [0] B01 (Coastal aerosol)
#   [1] B02 (Blue)
#   [2] B03 (Green)
#   [3] B04 (Red)
#   [9] B09 (Water vapour)
#   [10] B10 (SWIR cirrus)
#   [11] B11 (SWIR 1)
#   [12] B12 (SWIR 2)
# Saved normalization stats to checkpoints/MS_batchnorm_3conv_bands0_1_2_3_9_10_11_12_full_stats.json
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 64, 64, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 64, 64, 8)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 64)     │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 62, 62, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 29, 29, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 29, 29, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        92,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 467,210 (1.78 MB)
#  Trainable params: 466,314 (1.78 MB)
#  Non-trainable params: 896 (3.50 KB)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: 180240 (180240-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run ph7bw71a (0.3s)
# wandb: ⣾ setting up run ph7bw71a (0.3s)
# wandb: ⣷ setting up run ph7bw71a (0.3s)
# wandb: ⣯ setting up run ph7bw71a (0.3s)
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /content/deep-learning-eurosat/wandb/run-20260428_102112-ph7bw71a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MS_batchnorm_3conv_bands0_1_2_3_9_10_11_12_full
# wandb: ⭐️ View project at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: 🚀 View run at https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/ph7bw71a
# Epoch 1/50
# I0000 00:00:1777371679.861578    4384 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 124s 341ms/step - accuracy: 0.7452 - loss: 0.7745 - val_accuracy: 0.8409 - val_loss: 0.4745 - learning_rate: 1.0000e-04
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 134s 336ms/step - accuracy: 0.8509 - loss: 0.4464 - val_accuracy: 0.8828 - val_loss: 0.3683 - learning_rate: 1.0000e-04
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 336ms/step - accuracy: 0.8833 - loss: 0.3554 - val_accuracy: 0.9156 - val_loss: 0.2669 - learning_rate: 1.0000e-04
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 115s 339ms/step - accuracy: 0.8969 - loss: 0.3072 - val_accuracy: 0.8948 - val_loss: 0.3516 - learning_rate: 1.0000e-04
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 116s 342ms/step - accuracy: 0.9080 - loss: 0.2763 - val_accuracy: 0.9341 - val_loss: 0.2270 - learning_rate: 1.0000e-04
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 116s 343ms/step - accuracy: 0.9155 - loss: 0.2537 - val_accuracy: 0.9161 - val_loss: 0.2665 - learning_rate: 1.0000e-04
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 116s 344ms/step - accuracy: 0.9275 - loss: 0.2252 - val_accuracy: 0.9307 - val_loss: 0.2385 - learning_rate: 1.0000e-04
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 140s 338ms/step - accuracy: 0.9296 - loss: 0.2125 - val_accuracy: 0.9465 - val_loss: 0.1815 - learning_rate: 1.0000e-04
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 139s 329ms/step - accuracy: 0.9366 - loss: 0.1905 - val_accuracy: 0.9380 - val_loss: 0.2121 - learning_rate: 1.0000e-04
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 110s 325ms/step - accuracy: 0.9375 - loss: 0.1852 - val_accuracy: 0.9320 - val_loss: 0.2170 - learning_rate: 1.0000e-04
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 330ms/step - accuracy: 0.9424 - loss: 0.1769 - val_accuracy: 0.9487 - val_loss: 0.1640 - learning_rate: 1.0000e-04
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 331ms/step - accuracy: 0.9440 - loss: 0.1697 - val_accuracy: 0.9474 - val_loss: 0.1901 - learning_rate: 1.0000e-04
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9474 - loss: 0.1608 - val_accuracy: 0.9515 - val_loss: 0.1642 - learning_rate: 1.0000e-04
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9481 - loss: 0.1572 - val_accuracy: 0.9396 - val_loss: 0.2055 - learning_rate: 1.0000e-04
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 334ms/step - accuracy: 0.9512 - loss: 0.1466 - val_accuracy: 0.9531 - val_loss: 0.1561 - learning_rate: 1.0000e-04
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 330ms/step - accuracy: 0.9518 - loss: 0.1481 - val_accuracy: 0.9411 - val_loss: 0.1982 - learning_rate: 1.0000e-04
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9549 - loss: 0.1396 - val_accuracy: 0.9463 - val_loss: 0.1852 - learning_rate: 1.0000e-04
# Epoch 18/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9549 - loss: 0.1367 - val_accuracy: 0.9450 - val_loss: 0.1962 - learning_rate: 1.0000e-04
# Epoch 19/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9581 - loss: 0.1299 - val_accuracy: 0.9361 - val_loss: 0.2221 - learning_rate: 1.0000e-04
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 334ms/step - accuracy: 0.9611 - loss: 0.1209 - val_accuracy: 0.9413 - val_loss: 0.1983 - learning_rate: 1.0000e-04
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 336ms/step - accuracy: 0.9598 - loss: 0.1229 - val_accuracy: 0.9346 - val_loss: 0.2378 - learning_rate: 1.0000e-04
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9608 - loss: 0.1204 - val_accuracy: 0.9180 - val_loss: 0.2974 - learning_rate: 1.0000e-04
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 334ms/step - accuracy: 0.9584 - loss: 0.1250 - val_accuracy: 0.9515 - val_loss: 0.1711 - learning_rate: 1.0000e-04
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 334ms/step - accuracy: 0.9692 - loss: 0.0911 - val_accuracy: 0.9600 - val_loss: 0.1413 - learning_rate: 5.0000e-05
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9706 - loss: 0.0898 - val_accuracy: 0.9622 - val_loss: 0.1285 - learning_rate: 5.0000e-05
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9708 - loss: 0.0908 - val_accuracy: 0.9587 - val_loss: 0.1393 - learning_rate: 5.0000e-05
# Epoch 27/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 142s 328ms/step - accuracy: 0.9719 - loss: 0.0846 - val_accuracy: 0.9678 - val_loss: 0.1138 - learning_rate: 5.0000e-05
# Epoch 28/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9743 - loss: 0.0779 - val_accuracy: 0.9619 - val_loss: 0.1305 - learning_rate: 5.0000e-05
# Epoch 29/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 110s 326ms/step - accuracy: 0.9723 - loss: 0.0835 - val_accuracy: 0.9483 - val_loss: 0.1758 - learning_rate: 5.0000e-05
# Epoch 30/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - accuracy: 0.9731 - loss: 0.0818 - val_accuracy: 0.9572 - val_loss: 0.1473 - learning_rate: 5.0000e-05
# Epoch 31/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9748 - loss: 0.0789 - val_accuracy: 0.9593 - val_loss: 0.1435 - learning_rate: 5.0000e-05
# Epoch 32/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 112s 332ms/step - accuracy: 0.9734 - loss: 0.0801 - val_accuracy: 0.9576 - val_loss: 0.1426 - learning_rate: 5.0000e-05
# Epoch 33/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 110s 324ms/step - accuracy: 0.9743 - loss: 0.0777 - val_accuracy: 0.9526 - val_loss: 0.1721 - learning_rate: 5.0000e-05
# Epoch 34/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 109s 321ms/step - accuracy: 0.9738 - loss: 0.0775 - val_accuracy: 0.9524 - val_loss: 0.1636 - learning_rate: 5.0000e-05
# Epoch 35/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 144s 326ms/step - accuracy: 0.9745 - loss: 0.0756 - val_accuracy: 0.9556 - val_loss: 0.1524 - learning_rate: 5.0000e-05
# Epoch 36/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 109s 323ms/step - accuracy: 0.9780 - loss: 0.0637 - val_accuracy: 0.9487 - val_loss: 0.1746 - learning_rate: 2.5000e-05
# Epoch 37/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 142s 322ms/step - accuracy: 0.9799 - loss: 0.0628 - val_accuracy: 0.9604 - val_loss: 0.1340 - learning_rate: 2.5000e-05
# Epoch 38/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 110s 325ms/step - accuracy: 0.9795 - loss: 0.0617 - val_accuracy: 0.9628 - val_loss: 0.1274 - learning_rate: 2.5000e-05
# Epoch 39/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9795 - loss: 0.0596 - val_accuracy: 0.9663 - val_loss: 0.1160 - learning_rate: 2.5000e-05
# Epoch 40/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 114s 338ms/step - accuracy: 0.9799 - loss: 0.0575 - val_accuracy: 0.9633 - val_loss: 0.1276 - learning_rate: 2.5000e-05
# Epoch 41/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - accuracy: 0.9809 - loss: 0.0569 - val_accuracy: 0.9535 - val_loss: 0.1690 - learning_rate: 2.5000e-05
# Epoch 42/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 110s 326ms/step - accuracy: 0.9814 - loss: 0.0563 - val_accuracy: 0.9604 - val_loss: 0.1353 - learning_rate: 2.5000e-05
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading history steps 41-41, summary, console lines 83-83 (0.2s)
# wandb: ⣽ uploading history steps 41-41, summary, console lines 83-83 (0.2s)
# wandb:
# wandb: Run history:
# wandb:      epoch/accuracy ▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████████
# wandb:         epoch/epoch ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██
# wandb: epoch/learning_rate ██████████████████████▃▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁▁
# wandb:          epoch/loss █▅▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  epoch/val_accuracy ▁▃▅▄▆▅▆▇▆▆▇▇▇▆▇▇▇▇▆▇▅▇██▇██▇▇█▇▇▇▇▇█████
# wandb:      epoch/val_loss █▆▄▆▃▄▃▂▃▃▂▂▂▃▂▃▂▃▃▃▅▂▂▁▁▁▁▂▂▂▂▂▂▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch/accuracy 0.98139
# wandb:         epoch/epoch 41
# wandb: epoch/learning_rate 2e-05
# wandb:          epoch/loss 0.05634
# wandb:  epoch/val_accuracy 0.96037
# wandb:      epoch/val_loss 0.13533
# wandb:
# wandb: 🚀 View run MS_batchnorm_3conv_bands0_1_2_3_9_10_11_12_full at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn/runs/ph7bw71a
# wandb: ⭐️ View project at: https://wandb.ai/180240-h-gskulen-p-vestlandet/eurosat-cnn
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260428_102112-ph7bw71a/logs

# %%
# !python src/evaluate.py
# Out:
# 2026-04-28 11:56:08.906378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777377368.927404   28658 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777377368.934162   28658 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777377368.950118   28658 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777377368.950159   28658 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777377368.950164   28658 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777377368.950176   28658 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-28 11:56:08.954585: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 27000 images | 21600 train, 5400 val | 8 bands
# Estimating normalisation stats from 2000 training images...
# Sampling: 100% 2000/2000 [00:04<00:00, 420.67it/s]
# 2026-04-28 11:56:18.739984: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1777377378.741499   28658 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777377382.263979   28718 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-28 11:56:47.424915: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation accuracy: 0.9678  (96.78%)
#                       precision    recall  f1-score   support
#
#           AnnualCrop       0.98      0.97      0.97       610
#               Forest       0.99      0.99      0.99       598
# HerbaceousVegetation       0.98      0.97      0.97       605
#              Highway       0.96      0.90      0.93       523
#           Industrial       0.96      0.97      0.96       500
#              Pasture       0.95      0.97      0.96       383
#        PermanentCrop       0.95      0.95      0.95       506
#          Residential       0.94      1.00      0.97       608
#                River       0.96      0.97      0.96       494
#              SeaLake       0.99      0.99      0.99       573
#
#             accuracy                           0.97      5400
#            macro avg       0.97      0.97      0.97      5400
#         weighted avg       0.97      0.97      0.97      5400
#
# Figure(1000x800)
